# %%
import pandas as pd, matplotlib.pyplot as plt


print("DONE")
wts = [3.24, 4.01, 3.08, 3.56, 3.34, 3.43, 2.98, 3.81, 3.29,
       3.52, 3.47, 3.38, 3.31, 3.19, 3.21, 3.35, 3.17, 3.22, 3.31, 3.41]
n, bins, patches = plt.hist(wts, range=(2.9, 4.1), bins=12,
                            color='g', ec='black')
plt.xlabel("Weight (g)", fontsize=20, labelpad=10)
plt.xticks(fontsize=16)
plt.ylabel("Frequency", fontsize=20, labelpad=15)
plt.yticks(fontsize=16)

plt.title(str(len(wts)) + " Ridgenose Rattlers", fontsize=24, pad=15)
# Out:
# DONE
# Text(0.5, 1.0, '20 Ridgenose Rattlers')
